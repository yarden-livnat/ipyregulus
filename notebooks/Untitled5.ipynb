# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.linspace(0.72, 1.67, 100)*0.58826084

# %%
def f(x):
    return 4.46933564*x -1.93693098*x*x

# %%
y= f(x)

# %%
plt.plot(x, y, linewidth=2)
